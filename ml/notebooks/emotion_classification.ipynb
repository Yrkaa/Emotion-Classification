# %%
# Импорты
import yaml
import os
import shutil

from PIL import Image

import pandas as pd

import torch

from torch.utils.data import Dataset, DataLoader, random_split

from torchvision.transforms import v2 as transform

from tqdm import tqdm

from torchmetrics.classification import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score

from torch import nn


from torchvision.models import ResNet18_Weights, resnet18

from sklearn.model_selection import train_test_split

# %%
# Загрузка данных из конфига
with open(r"..\config\main.yaml") as file:
    cfg = yaml.safe_load(file)

base_path = os.path.abspath("..").replace("\\", "/")
raw_image_path = base_path + "/" + cfg["data"]["raw_img"]
processed_image_path = base_path + "/" + cfg["data"]["processed_img"]
annotation_path = "../" + cfg["data"]["csv_annotation"]
class_map = cfg["data"]["class_map"]

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Подготовка CSV

# %% [markdown]
# Сначала для удобства подготовим аннотационный CSV-файл. В нем будут столбцы с путями к неподготовленным и подготовленным картинкам, типами (train или test) и классами.

# %% [markdown]
# Напишем код, который будет проходиться по всем файлам датасета и заносить их в аннотацию:

# %%
# Код для подготовки аннотационного CSV-файла

# Столбцы
raw_path_list = [] # Пути в необработанном датасете
processed_path_list = [] # Пути в обработанном датасете
type_list = [] # Тип картинки (train или test)
class_list = [] # Класс картинки

# Цикл для прохода по всем файлам
for type_name in os.listdir(raw_image_path):
    for class_name in os.listdir(raw_image_path+"/"+type_name):
        for file_name in os.listdir(raw_image_path+"/"+type_name+"/"+class_name):
            
            # Добавление строки
            raw_path_list.append(raw_image_path+"/"+type_name+"/"+class_name+"/"+file_name)
            processed_path_list.append(processed_image_path+"/"+type_name+"/"+class_name+"/"+file_name)
            type_list.append(type_name)
            class_list.append(class_name)

# Создание DataFrame
annotation = pd.DataFrame({"raw_img_path": raw_path_list, "processed_img_path": processed_path_list, 
    "type": type_list, "class": class_list})

# Вывод нескольких строк для примера
annotation.head(5)
# Out:
#                                         raw_img_path  \
# 0  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 1  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 2  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 3  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 4  c:/MyProjects/Python/PyTorch/Emotions Classifi...
#
#                                   processed_img_path  type  class
# 0  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 1  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 2  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 3  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 4  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry

# %% [markdown]
# Сохраним аннотацию по пути из конфига:

# %%
# Сохранение аннотации
annotation.to_csv(annotation_path)

# %% [markdown]
# ## Подготовка изображений

# %% [markdown]
# Здесь мы проведем предобработку изображений.

# %% [markdown]
# Создадим функцию, которая будет предобрабатывать изображения(пока что нам ничего такого не надо, кроме перевода в из L в RGB):

# %%
# Функция для предобработки изображения
def process_img(img_path):

    # Открываем картинку
    img = Image.open(img_path)

    # Конвертируем картинку в RGB
    img = img.convert("RGB")

    # Возвращаем обработанную картинку
    return img

# %% [markdown]
# Теперь переместим файлы датасета по нужному пути:

# %%
# Перемещение файлов

# Счётчики для статистики
copied_count = 0 # Скопировано
overwritten_count = 0 # Перезаписано
error_count = 0 # Ошибок

# Цикл с проходом по всем строкам датасета
for idx, row in annotation.iterrows():
    src_path = row['raw_img_path'] # Старый путь
    dst_path = row['processed_img_path'] # Новый путь
    
    try:
        # 1. Создаём директорию назначения, если её нет
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        
        # 2. Проверяем, существует ли файл уже (для статистики)
        if os.path.exists(dst_path):
            overwritten_count += 1
        else:
            copied_count += 1
        
        # 3. Получаем обработанную картинку
        proceed_img = process_img(src_path)

        # 4. Сохраняем картинку по нужному пути
        proceed_img.save(dst_path)
        
    except Exception as e:
        error_count += 1
        print(f"❌ Ошибка при копировании {src_path}: {e}")

print("Копирование завершено!")
print(f"Всего файлов: {len(annotation)}")
print(f"Скопировано новых: {copied_count}")
print(f"Перезаписано существующих: {overwritten_count}")
print(f"Ошибок: {error_count}")
# Out:
# Копирование завершено!
# Всего файлов: 35887
# Скопировано новых: 0
# Перезаписано существующих: 35887
# Ошибок: 0

# %% [markdown]
# # Подготовка данных для модели

# %% [markdown]
# Теперь, когда мы переработали датасет, можно приступить к подготовке данных для подачи в модель. Для этого надо создать класс датасета, разделить его на тренировочную и тестовую выборку, а затем подготовить DataLoader`ы.

# %% [markdown]
# Создадим класс датасета:

# %%
class ImageDataset(Dataset):

    # Инициализация
    def __init__(self, img_path_list, labels_list, transforms = None):

        # Инициализация параметров
        self.img_path_list = img_path_list
        self.labels_list = labels_list
        self.transforms = transforms
    
    # Получение длины датасета
    def __len__(self):

        return len(self.img_path_list)

    # Получение экземпляра из датасета
    def __getitem__(self, idx):

        # Получение пути к картинке и ее индекса
        img_path = self.img_path_list[idx]
        label = self.labels_list[idx]

        # Загрузка картинки
        img = Image.open(img_path).convert('RGB')

        # Применение преобразований
        if self.transforms:
            for t in self.transforms:
                img = t(img)

        # Возвращаем ответ
        return img, torch.tensor(label)

# %% [markdown]
# Теперь определим преобразования к картинкам:

# %%
train_transforms = transform.Compose([
    transform.RandomHorizontalFlip(p=0.5),
    transform.RandomRotation(degrees=10),  
    # transform.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),  
    # transform.RandomAffine(degrees=0, translate=(0.1, 0.1)),  
    # transform.RandomGrayscale(p=0.1),
    transform.RandomResizedCrop(224, scale=(0.85, 1.0)),
    # transform.GaussianBlur(kernel_size=3, sigma=(0.1, 0.5)),
])

# %% [markdown]
# Создадим датасет и разделим его на тренировчный и тестовый:

# %%
# Разделение датасета
train_df, test_df = train_test_split(annotation, test_size=0.2, stratify=annotation["class"], random_state=42)

# Инициализация классов датасета
train_ds = ImageDataset(train_df["processed_img_path"].values, labels_list = train_df["class"].values, 
    transforms = [train_transforms, ResNet18_Weights.DEFAULT.transforms()])

test_ds = ImageDataset(test_df["processed_img_path"].values, labels_list = 
    test_df["class"].values, transforms = [ResNet18_Weights.DEFAULT.transforms()])

# %% [markdown]
# Осталось создать DataLoader`ы:

# %%
# Создание загрузчиков данных

BATCH_SIZE = 8 # Размер батча

train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True) # Для обучения
test_dl = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False) # Для тестирования

# %% [markdown]
# # Инициализация модели

# %% [markdown]
# Мы постоим собственную маленькую CNN модель:

# %%
# Инициализация модели
model = resnet18(weights=ResNet18_Weights.DEFAULT)
for param in model.parameters():
    param.requires_grad = False
for param in model.layer4.parameters():
    param.requires_grad = True
model.fc = nn.Sequential(
    nn.Dropout(0.4),
    nn.Linear(model.fc.in_features, len(class_map))
)

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
model(next(iter(train_dl))[0]).shape
# Out:
# torch.Size([8, 8])

# %% [markdown]
# # Обучение модели

# %% [markdown]
# Приступим к обучению. Сначала определим функцию потерь и алгорит оптимизации:

# %%
loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0.1) # Функция потерь
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4, weight_decay=8e-3) # Оптимизатор

# %%
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=3)

# %% [markdown]
# Теперь пропишем алгоритм обучения модели:

# %%
# Обучение модели

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # Устройство запуска модели(GPU или CPU)
model = model.to(device)  # Ваша модель
num_classes = 8           # Количество эмоций
num_epochs = 20          # Количество эпох

# Зерно для рандомных операций
torch.manual_seed(42)

# Метрики
metrics = {
    'acc': MulticlassAccuracy(num_classes=num_classes, average='macro').to(device),
    'prec': MulticlassPrecision(num_classes=num_classes, average='macro').to(device),
    'rec': MulticlassRecall(num_classes=num_classes, average='macro').to(device),
    'f1': MulticlassF1Score(num_classes=num_classes, average='macro').to(device),
}

# Списки для хранения информации по эпохам
history = {
    'train_loss': [], 'train_acc': [], 'train_prec': [], 'train_rec': [], 'train_f1': [],
    'val_loss': [], 'val_acc': [], 'val_prec': [], 'val_rec': [], 'val_f1': []
}

# Цикл обучения
print(f"Начало обучения на {device}...")
print(f"Epochs: {num_epochs} | Classes: {num_classes}\n")

for epoch in range(num_epochs):
    
    # Сброс метрик перед эпохой
    for metric in metrics.values():
        metric.reset()

    # Тренировка
    model.train()
    train_loss = 0.0

    # Progress bar для train
    train_loader_tqdm = tqdm(train_dl, desc = f"Тренировка на эпохе {epoch+1}", leave=False)
    
    for images, labels in train_loader_tqdm:

        # Переводи данных на нужной устройство
        images, labels = images.to(device), labels.to(device)
        
        # Основные шаги обучения(сброс прошлых градиентов, вычисление потерь, обратное распространение ошибки, обновление весов)
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # Обновление общих потерь
        train_loss += loss.item() * images.size(0)
        
        # Обновление метрик
        # preds = torch.argmax(outputs, dim=1)
        for metric in metrics.values():
            metric.update(outputs, labels)
        
        # Обновление прогресс-бара
        train_loader_tqdm.set_postfix({
            'loss': f'{loss.item():.4f}',
            'accuracy': f'{metrics["acc"].compute():.4f}'
        })
    
    # Вычисление итоговых метрик за эпоху (Train)
    train_loss /= len(train_dl.dataset)
    train_metrics = {name: metric.compute().item() for name, metric in metrics.items()}
    
    # Сохранение в историю
    history['train_loss'].append(train_loss)
    for key, val in train_metrics.items():
        history[f'train_{key}'].append(val)
    
    # Валидация
    model.eval()
    val_loss = 0.0
    
    # Сброс метрик перед валидацией
    for metric in metrics.values():
        metric.reset()
    
    # Progress bar для val
    val_loader_tqdm = tqdm(test_dl, desc=f"Валидация на эпохе {epoch+1}", leave=False)
    
    with torch.no_grad():
        for images, labels in val_loader_tqdm:

            # Перевод данных на нужный девайс
            images, labels = images.to(device), labels.to(device)
            
            # Получение ответов от модели и вычисление потерь
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            
            # Суммируем потери
            val_loss += loss.item() * images.size(0)
            
            # Обновление метрик
            preds = torch.argmax(outputs, dim=1)
            for metric in metrics.values():
                metric.update(preds, labels)
            
            val_loader_tqdm.set_postfix({
                'loss': f'{loss.item():.4f}',
                'accuracy': f'{metrics["acc"].compute():.4f}'
            })
    
    # Вычисление итоговых метрик за эпоху (Val)
    val_loss /= len(test_dl.dataset)
    val_metrics = {name: metric.compute().item() for name, metric in metrics.items()}
    
    # Сохранение в историю
    history['val_loss'].append(val_loss)
    for key, val in val_metrics.items():
        history[f'val_{key}'].append(val)

    # Обновление шедулера(регулировка lr)
    lr_scheduler.step(val_metrics['acc'])
    
    # Вывод результатов эпохи
    print(f"Epoch {epoch+1} Results:")
    print(f"  Train Loss: {train_loss:.4f} | Acc: {train_metrics['acc']:.4f} | F1: {train_metrics['f1']:.4f}")
    print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_metrics['acc']:.4f} | F1: {val_metrics['f1']:.4f}")

# Финальный отчет
print("\n\n✅ Обучение завершено!")
print(f"🏆 Best Val Accuracy: {max(history['val_acc']):.4f} (Epoch {history['val_acc'].index(max(history['val_acc']))+1})")
print(f"🏆 Best Val F1 Score: {max(history['val_f1']):.4f} (Epoch {history['val_f1'].index(max(history['val_f1']))+1})")
# Out:
# Начало обучения на cpu...
# Epochs: 20 | Classes: 8
# Epoch 1 Results:
#   Train Loss: 2.4703 | Acc: 0.1000 | F1: 0.0867
#   Val   Loss: 2.4969 | Acc: 0.0000 | F1: 0.0000
# Epoch 2 Results:
#   Train Loss: 2.0203 | Acc: 0.2656 | F1: 0.2615
#   Val   Loss: 2.6520 | Acc: 0.0000 | F1: 0.0000
# Epoch 3 Results:
#   Train Loss: 1.8587 | Acc: 0.3568 | F1: 0.3483
#   Val   Loss: 2.7206 | Acc: 0.0000 | F1: 0.0000
# Epoch 4 Results:
#   Train Loss: 1.7474 | Acc: 0.3807 | F1: 0.3842
#   Val   Loss: 2.8555 | Acc: 0.0000 | F1: 0.0000
# Epoch 5 Results:
#   Train Loss: 1.5388 | Acc: 0.5130 | F1: 0.5093
#   Val   Loss: 2.8970 | Acc: 0.0625 | F1: 0.0708
# Epoch 6 Results:
#   Train Loss: 1.3510 | Acc: 0.5396 | F1: 0.5326
#   Val   Loss: 2.8371 | Acc: 0.1250 | F1: 0.1399
# Epoch 7 Results:
#   Train Loss: 1.3671 | Acc: 0.6375 | F1: 0.6352
#   Val   Loss: 2.8688 | Acc: 0.1250 | F1: 0.1333
# Epoch 8 Results:
#   Train Loss: 1.3405 | Acc: 0.6292 | F1: 0.6256
# ...

# %%
len(test_df)
# Out:
# 31
