# %%
# Импорты
import yaml
import os
import shutil

import random

import matplotlib.pyplot as plt
import seaborn as sbn

from PIL import Image

import pandas as pd

import torch

from torch.utils.data import Dataset, DataLoader, random_split

from torchvision.transforms import v2 as transform

from tqdm import tqdm

from torchmetrics.classification import MulticlassAccuracy, MulticlassPrecision, MulticlassRecall, MulticlassF1Score
from sklearn.metrics import confusion_matrix

from torch import nn

from torchvision.models import ResNet18_Weights, resnet18

from sklearn.model_selection import train_test_split

# %%
# Загрузка данных из конфига
with open(r"..\config\main.yaml") as file:
    cfg = yaml.safe_load(file)

base_path = os.path.abspath("..").replace("\\", "/")
raw_image_path = base_path + "/" + cfg["data"]["raw_img"]
processed_image_path = base_path + "/" + cfg["data"]["processed_img"]
annotation_path = "../" + cfg["data"]["csv_annotation"]
class_map = cfg["data"]["class_map"]

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Подготовка CSV

# %% [markdown]
# Сначала для удобства подготовим аннотационный CSV-файл. В нем будут столбцы с путями к неподготовленным и подготовленным картинкам, типами (train или test) и классами.

# %% [markdown]
# Напишем код, который будет проходиться по всем файлам датасета и заносить их в аннотацию:

# %%
# Код для подготовки аннотационного CSV-файла

# Столбцы
raw_path_list = [] # Пути в необработанном датасете
processed_path_list = [] # Пути в обработанном датасете
type_list = [] # Тип картинки (train или test)
class_list = [] # Класс картинки

# Цикл для прохода по всем файлам
for type_name in os.listdir(raw_image_path):
    for class_name in os.listdir(raw_image_path+"/"+type_name):
        for file_name in os.listdir(raw_image_path+"/"+type_name+"/"+class_name):
            
            # Добавление строки
            raw_path_list.append(raw_image_path+"/"+type_name+"/"+class_name+"/"+file_name)
            processed_path_list.append(processed_image_path+"/"+type_name+"/"+class_name+"/"+file_name)
            type_list.append(type_name)
            class_list.append(class_name)

# Создание DataFrame
annotation = pd.DataFrame({"raw_img_path": raw_path_list, "processed_img_path": processed_path_list, 
    "type": type_list, "class": class_list})

# Вывод нескольких строк для примера
annotation.head(5)
# Out:
#                                         raw_img_path  \
# 0  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 1  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 2  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 3  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 4  c:/MyProjects/Python/PyTorch/Emotions Classifi...
#
#                                   processed_img_path  type  class
# 0  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 1  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 2  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 3  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry
# 4  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test  angry

# %% [markdown]
# Сохраним аннотацию по пути из конфига:

# %%
# Сохранение аннотации
annotation.to_csv(annotation_path)

# %% [markdown]
# ## Подготовка изображений

# %% [markdown]
# Здесь мы проведем предобработку изображений.

# %% [markdown]
# Создадим функцию, которая будет предобрабатывать изображения(по факту преобразования лучше использовать на лету, но для примера я сделал и такой код):

# %%
# Функция для предобработки изображения
# def process_img(img_path):

#     # Открываем картинку
#     img = Image.open(img_path)

#     # Конвертируем картинку в RGB
#     img = img.convert("RGB")

#     # Возвращаем обработанную картинку
#     return img

# %% [markdown]
# Теперь переместим файлы датасета по нужному пути, предварительно обработав их:

# %%
# Перемещение файлов

# # Счётчики для статистики
# copied_count = 0 # Скопировано
# overwritten_count = 0 # Перезаписано
# error_count = 0 # Ошибок

# # Цикл с проходом по всем строкам датасета
# for idx, row in annotation.iterrows():
#     src_path = row['raw_img_path'] # Старый путь
#     dst_path = row['processed_img_path'] # Новый путь
    
#     try:
#         # 1. Создаём директорию назначения, если её нет
#         os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        
#         # 2. Проверяем, существует ли файл уже (для статистики)
#         if os.path.exists(dst_path):
#             overwritten_count += 1
#         else:
#             copied_count += 1
        
#         # 3. Получаем обработанную картинку
#         proceed_img = process_img(src_path)

#         # 4. Сохраняем картинку по нужному пути
#         proceed_img.save(dst_path)
        
#     except Exception as e:
#         error_count += 1
#         print(f"❌ Ошибка при копировании {src_path}: {e}")

# print("Копирование завершено!")
# print(f"Всего файлов: {len(annotation)}")
# print(f"Скопировано новых: {copied_count}")
# print(f"Перезаписано существующих: {overwritten_count}")
# print(f"Ошибок: {error_count}")

# %% [markdown]
# # Подготовка данных для модели

# %% [markdown]
# Теперь, когда мы переработали датасет, можно приступить к подготовке данных для подачи в модель. Для этого надо создать класс датасета, разделить его на тренировочную и тестовую выборку, а затем подготовить DataLoader`ы. Дополнительно потребуется encoding категориальных данных, определение весов для классов и преобразований для картинок.

# %% [markdown]
# Создадим класс датасета:

# %%
# Класс датасета

class ImageDataset(Dataset):

    # Инициализация
    def __init__(self, img_path_list, labels_list, transforms = None):

        # Инициализация параметров
        self.img_path_list = img_path_list
        self.labels_list = labels_list
        self.transforms = transforms
    
    # Получение длины датасета
    def __len__(self):

        return len(self.img_path_list)

    # Получение экземпляра из датасета
    def __getitem__(self, idx):

        # Получение пути к картинке и ее индекса
        img_path = self.img_path_list[idx]
        label = self.labels_list[idx]

        # Загрузка картинки
        img = Image.open(img_path).convert('RGB')

        # Применение преобразований
        if self.transforms:
            for t in self.transforms:
                img = t(img)

        # Возвращаем ответ
        return img, torch.tensor(label, dtype=torch.long)

# %% [markdown]
# Теперь определим преобразования к картинкам:

# %%
# Преобразования к картинкам
train_transforms = transform.Compose([
    transform.RandomHorizontalFlip(p=0.5),
    transform.RandomRotation(degrees=10),
])

base_transform = transform.Compose([
    transform.ToImage(),
    transform.ToDtype(dtype=torch.float32, scale=True),
    # transform.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)),
])

# %% [markdown]
# Сделаем Label Encoding для меток в аннотации:

# %%
# Label Encoding для меток класса

annotation = pd.read_csv(annotation_path) # Загружаем аннотацию по новой(так как при повторном 
    # запуске этого кода без этой строчки все просто станет Nan)

annotation["class"] = annotation["class"].map(class_map) # Encoding

# Выведем все для наглядности
print("Пропусков в метках:", annotation["class"].isna().sum())
annotation.head(5)
# Out:
# Пропусков в метках: 0
#    Unnamed: 0                                       raw_img_path  \
# 0           0  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 1           1  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 2           2  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 3           3  c:/MyProjects/Python/PyTorch/Emotions Classifi...
# 4           4  c:/MyProjects/Python/PyTorch/Emotions Classifi...
#
#                                   processed_img_path  type  class
# 0  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test      0
# 1  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test      0
# 2  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test      0
# 3  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test      0
# 4  c:/MyProjects/Python/PyTorch/Emotions Classifi...  test      0

# %% [markdown]
# Так как в EDA был увиден дизбаланс классов, мы сделаем Class Weight для балансировки. Для этого подсчитаем веса классов(потом передадим их в функцию потерь):

# %%
# Переменные для расчета
class_counts = annotation['class'].value_counts().sort_index().values # Размеры классов
n_samples = len(annotation) # Размер всего датасета
n_classes = len(class_map) # Количество классов

# Подсчет весов для классов
class_weights = n_samples / (n_classes * class_counts)

# Нормализация весов
class_weights = torch.tensor(class_weights / class_weights.min(), dtype=torch.float32)

class_weights
# Out:
# tensor([ 1.8149, 16.4333,  1.7553,  1.0000,  1.4503,  1.4792,  2.2461])

# %% [markdown]
# Создадим датасет и разделим его на тренировочный и тестовый:

# %%
# Создание датасетов

# Разделение датасета на тренировочный, тестовый и валидационный
train_df, val_df = train_test_split(annotation.where(annotation["type"] == "train").dropna(), 
    stratify=annotation.where(annotation["type"] == "train").dropna()["class"], test_size=0.15, random_state=42)
test_df = annotation.where(annotation["type"] == "test").dropna()

# Инициализация классов датасета
train_ds = ImageDataset(train_df["processed_img_path"].values, labels_list = train_df["class"].values, 
    transforms = [train_transforms, base_transform])

val_ds = ImageDataset(val_df["processed_img_path"].values, labels_list = val_df["class"].values, 
    transforms = [base_transform])

test_ds = ImageDataset(test_df["processed_img_path"].values, labels_list = 
    test_df["class"].values, transforms = [base_transform])

# %% [markdown]
# Осталось создать DataLoader`ы:

# %%
# Создание загрузчиков данных

BATCH_SIZE = 32 # Размер батча

train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True) # Для обучения
val_dl = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False) # Для валидации
test_dl = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False) # Для тестирования

# %% [markdown]
# # Инициализация модели

# %% [markdown]
# Мы создадим свою базовую модель на CNN:

# %%
# Инициализация модели
model = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(64),
    nn.MaxPool2d(2),
    nn.Dropout(p=0.25),

    nn.Conv2d(64, 128, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(128),
    nn.MaxPool2d(2),
    nn.Dropout(p=0.25),

    nn.Conv2d(128, 256, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(256),
    nn.MaxPool2d(2),
    nn.Dropout(p=0.25),

    nn.Conv2d(256, 512, kernel_size=3, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(512),
    nn.MaxPool2d(2),
    nn.Dropout(p=0.25),

    nn.Flatten(),

    nn.Linear(512*3*3, 256),
    nn.ReLU(),
    nn.BatchNorm1d(256),
    nn.Dropout(p=0.3),

    nn.Linear(256, 512),
    nn.ReLU(),
    nn.BatchNorm1d(512),
    nn.Dropout(p=0.3),
    
    nn.Linear(512, len(class_map))
)

# %% [markdown]
# Выведем структуру модели:

# %%
model
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): ReLU()
#   (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (4): Dropout(p=0.25, inplace=False)
#   (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (6): ReLU()
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (9): Dropout(p=0.25, inplace=False)
#   (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU()
#   (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (14): Dropout(p=0.25, inplace=False)
# ...

# %% [markdown]
# Проверим выход модели:

# %%
# Проверка выхода модели
model(next(iter(train_dl))[0]).shape
# Out:
# torch.Size([32, 7])

# %% [markdown]
# # Обучение модели

# %% [markdown]
# Приступим к обучению. Сначала выберем утсройство для обучения и инференса модели:

# %%
# Устройство запуска модели(GPU или CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') 

device
# Out:
# device(type='cuda')

# %% [markdown]
# Определим функцию потерь и алгорит оптимизации:

# %%
loss_fn = torch.nn.CrossEntropyLoss(weight=class_weights.to(device)) # Функция потерь
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4) # Оптимизатор

# %% [markdown]
# Создадим LR-scheduler для оптимизации LR:

# %%
lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2) # Оптимизатор LR

# %% [markdown]
# Теперь пропишем алгоритм обучения модели:

# %%
# Обучение модели

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') # Устройство запуска модели(GPU или CPU)

model = model.to(device)  # Переводим модель на нужное устройство

num_classes = len(class_map)         # Количество эмоций
num_epochs = 40          # Количество эпох

# Зерно для рандомных операций
torch.manual_seed(42)

# Метрики
metrics = {
    'acc': MulticlassAccuracy(num_classes=num_classes, average='macro').to(device),
    'prec': MulticlassPrecision(num_classes=num_classes, average='macro').to(device),
    'rec': MulticlassRecall(num_classes=num_classes, average='macro').to(device),
    'f1': MulticlassF1Score(num_classes=num_classes, average='macro').to(device),
}

# Списки для хранения информации по эпохам
history = {
    'train_loss': [], 'train_acc': [], 'train_prec': [], 'train_rec': [], 'train_f1': [],
    'val_loss': [], 'val_acc': [], 'val_prec': [], 'val_rec': [], 'val_f1': []
}

# Цикл обучения
print(f"Начало обучения на {device}...")
print(f"Epochs: {num_epochs} | Classes: {num_classes}\n")

for epoch in range(num_epochs):
    
    # Сброс метрик перед эпохой
    for metric in metrics.values():
        metric.reset()

    # Тренировка
    model.train()
    train_loss = 0.0

    # Progress bar для train
    train_loader_tqdm = tqdm(train_dl, desc = f"Тренировка на эпохе {epoch+1}", leave=False)
    
    for images, labels in train_loader_tqdm:

        # Переводи данных на нужной устройство
        images, labels = images.to(device), labels.to(device)
        
        # Основные шаги обучения(сброс прошлых градиентов, вычисление потерь, обратное распространение ошибки, обновление весов)
        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # Обновление общих потерь
        train_loss += loss.item() * images.size(0)
        
        # Обновление метрик
        for metric in metrics.values():
            metric.update(outputs, labels)
        
        # Обновление прогресс-бара
        train_loader_tqdm.set_postfix({
            'loss': f'{loss.item():.4f}',
            'accuracy': f'{metrics["acc"].compute():.4f}'
        })
    
    # Вычисление итоговых метрик за эпоху (Train)
    train_loss /= len(train_dl.dataset)
    train_metrics = {name: metric.compute().item() for name, metric in metrics.items()}
    
    # Сохранение в историю
    history['train_loss'].append(train_loss)
    for key, val in train_metrics.items():
        history[f'train_{key}'].append(val)
    
    # Валидация
    model.eval()
    val_loss = 0.0
    
    # Сброс метрик перед валидацией
    for metric in metrics.values():
        metric.reset()
    
    # Progress bar для val
    val_loader_tqdm = tqdm(val_dl, desc=f"Валидация на эпохе {epoch+1}", leave=False)
    
    with torch.no_grad():
        for images, labels in val_loader_tqdm:

            # Перевод данных на нужный девайс
            images, labels = images.to(device), labels.to(device)
            
            # Получение ответов от модели и вычисление потерь
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            
            # Суммируем потери
            val_loss += loss.item() * images.size(0)
            
            # Обновление метрик
            for metric in metrics.values():
                metric.update(outputs, labels)
            
            val_loader_tqdm.set_postfix({
                'loss': f'{loss.item():.4f}',
                'accuracy': f'{metrics["acc"].compute():.4f}'
            })
    
    # Вычисление итоговых метрик за эпоху (Val)
    val_loss /= len(val_dl.dataset)
    val_metrics = {name: metric.compute().item() for name, metric in metrics.items()}
    
    # Сохранение в историю
    history['val_loss'].append(val_loss)
    for key, val in val_metrics.items():
        history[f'val_{key}'].append(val)

    # Обновление шедулера(регулировка lr)
    lr_scheduler.step(val_metrics['f1'])
    
    # Вывод результатов эпохи
    print(f"Epoch {epoch+1} Results:")
    print(f"  Train Loss: {train_loss:.4f} | Acc: {train_metrics['acc']:.4f} | F1: {train_metrics['f1']:.4f}")
    print(f"  Val   Loss: {val_loss:.4f} | Acc: {val_metrics['acc']:.4f} | F1: {val_metrics['f1']:.4f}")

# Финальный отчет
print("\n\n✅ Обучение завершено!")
print(f"🏆 Best Val Accuracy: {max(history['val_acc']):.4f} (Epoch {history['val_acc'].index(max(history['val_acc']))+1})")
print(f"🏆 Best Val F1 Score: {max(history['val_f1']):.4f} (Epoch {history['val_f1'].index(max(history['val_f1']))+1})")
# Out:
# Начало обучения на cuda...
# Epochs: 40 | Classes: 7
# Epoch 1 Results:
#   Train Loss: 1.9593 | Acc: 0.2149 | F1: 0.1940
#   Val   Loss: 1.9284 | Acc: 0.2864 | F1: 0.2546
# Epoch 2 Results:
#   Train Loss: 1.7475 | Acc: 0.3183 | F1: 0.2842
#   Val   Loss: 1.7610 | Acc: 0.3829 | F1: 0.3256
# Epoch 3 Results:
#   Train Loss: 1.6082 | Acc: 0.3836 | F1: 0.3370
#   Val   Loss: 1.5158 | Acc: 0.4215 | F1: 0.3701
# Epoch 4 Results:
#   Train Loss: 1.5036 | Acc: 0.4230 | F1: 0.3766
#   Val   Loss: 1.5492 | Acc: 0.4111 | F1: 0.3522
# Epoch 5 Results:
#   Train Loss: 1.4553 | Acc: 0.4499 | F1: 0.3969
#   Val   Loss: 1.4347 | Acc: 0.4746 | F1: 0.4117
# Epoch 6 Results:
#   Train Loss: 1.3964 | Acc: 0.4719 | F1: 0.4171
#   Val   Loss: 1.3427 | Acc: 0.5010 | F1: 0.4488
# Epoch 7 Results:
#   Train Loss: 1.3783 | Acc: 0.4830 | F1: 0.4255
#   Val   Loss: 1.4962 | Acc: 0.4996 | F1: 0.4274
# Epoch 8 Results:
#   Train Loss: 1.3227 | Acc: 0.5060 | F1: 0.4480
# ...

# %% [markdown]
# Выведем графики метрик и потерь на обучении и валидации:

# %%
# Вывод графиков метрик и потерь

# Получение названий метрик
parameters_names = [name.split("_")[1] for name in history.keys()]
num_metrics = int(0.5*len(parameters_names))
parameters_names = parameters_names[:num_metrics]

# Настройка размеров графиков
plt.figure(figsize=(24, 6))

# Вывод графиков
for i, parameter in enumerate(parameters_names):
    plt.subplot(1, 5, i+1) # Положение
    plt.title(parameter) # Имя метрики
    plt.plot(history[f"val_{parameter}"], label="val") # Кривая валидации
    plt.plot(history[f"train_{parameter}"], label="train") # Кривая обучения
    plt.legend()

# Показ
plt.show()

# %% [markdown]
# Сохраним нашу модель:

# %%
# Сохранение модели

# Получение финального accuracy(нужно для названия сохраненной модели)
final_acc = round(history['val_acc'][-1]*100)

torch.save(model, f"../models/model_acc_{final_acc}.pth" ) # Сохранение всей модели
torch.save(model.state_dict(), f"../models/model_state_dict_acc_{final_acc}.pth") # Сохранение весов модели

# %% [markdown]
# # Тестирование

# %% [markdown]
# После обучения мы можем приступить к тестированию:

# %%
# Тестирование

# Progress bar для тестирования
test_loader_tqdm = tqdm(test_dl, desc=f"Тестирование", leave=False)

# Списки предсказаний и ответов(понадобится для confusion matrix)
all_preds = []
all_labels = []

# Сброс метрик с обучения и валидации
for metric in metrics.values():
    metric.reset()

model.eval() # Модель в режим оценки

with torch.no_grad(): # Отключаем градиенты

    # Цикл тестирования
    for images, labels in test_loader_tqdm:

        # Перевод данных на нужный девайс
        images, labels = images.to(device), labels.to(device)
        
        # Получение ответов от модели и вычисление потерь
        outputs = model(images)
        
        # Обновление метрик
        for metric in metrics.values():
            metric.update(outputs, labels)
        
        # Вывод результатов для батча
        test_loader_tqdm.set_postfix({
                'accuracy': f'{metrics["acc"].compute():.4f}',
                'precision': f'{metrics["prec"].compute():.4f}',
                'recall': f'{metrics["rec"].compute():.4f}',
                'f1': f'{metrics["f1"].compute():.4f}'
            })

        # Сохранение ответов и предсказаний модели
        all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Вывод общих результатов тестирования
print("Результаты тестирования:")
for name, metric in metrics.items():
    print(f"  {name}: {metric.compute():.4f}")
# Out:
# Результаты тестирования:
#   acc: 0.6272
#   prec: 0.6008
#   rec: 0.6272
#   f1: 0.6092

# %% [markdown]
# Помимо вывода метрик мы построим матрицу ошибок модели для более полного понимания ее работы:

# %%
# Вывод матрицы ошибок

# Получение значений для матрицы
cm = confusion_matrix(all_labels, all_preds)

# Получение списка названий классов для красивого вывода графика
labels_names = [v for v in class_map.keys()]

# Настройка размерво графика
plt.figure(figsize=(8,6))

# Вывод матрицы
sbn.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels_names, yticklabels=labels_names)

# Настройка вывода
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")

# Показ
plt.show()

# %% [markdown]
# Наконец, выведем несколько примеров картинок и предсказаний модели для наглядности:

# %%
# Вывод нескольких примеров изображений с предсказаниями моделей

plt.figure(figsize=(24, 12)) # Настройка размеров изображений

for _ in range(5): 

    # Получение картинки и ответа из датасета(рандомно)
    obj_id = random.randint(0, len(test_ds))
    img, label = test_ds[obj_id]

    # Получение ответа модели
    pred = torch.argmax(model(img.unsqueeze(0).to(device)), dim=1)

    # Переворачиваем словарь классов для вывода названия эмоции вместо id класса
    class_map_reverse = {v: k for k, v in class_map.items()}

    # Вывод картинки
    plt.subplot(1, 5, _+1) # Положение
    plt.imshow(img.cpu().permute(1, 2, 0)) # Сама картинка
    plt.title(f"Model:  {class_map_reverse[pred.item()]}, Real: {class_map_reverse[label.item()]}") # Надпись с ответом модели и реальной эмоцией
    plt.axis('off') # Отключение осей координат

# Показ
plt.show()

# %% [markdown]
# # Небольшой анализ результатов

# %% [markdown]
# Хоть полученная точность и кажется маленькой (всего 60-62%), но на самом деле все не так плохо. Ограничения качества во многом связаны с особенностями самого датасета. Во-первых, изображения имеют низкое разрешение (48×48 пикселей), что существенно ограничивает возможность модели извлекать детализированные признаки лица. Во-вторых, многие эмоции визуально схожи между собой. Например, по матрице ошибок видно, что модель лучше всего распознаёт «радость», что объясняется наличием ярко выраженного признака — улыбки. В то же время такие эмоции, как «страх» и «грусть», часто путаются, поскольку имеют пересекающиеся визуальные характеристики (например, приоткрытый рот или широко раскрытые глаза). К тому же, выражение эмоций у разных людей может кардинально отличаться, что также мешает модели более точно определять эмоции. В довершение, полученные результаты соответствуют типичным метрикам для данного датасета: большинство базовых моделей на FER-2013 достигают точности в диапазоне 60–65%.
